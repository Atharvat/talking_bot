# %%
# %tensorflow_version 1.x
# !pip install gpt-2-simple
import gpt_2_simple as gpt2
# Out:
# TensorFlow 1.x selected.
# ...
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %%
gpt2.download_gpt2(model_name="124M")
# Out:
# Fetching checkpoint: 1.05Mit [00:00, 656Mit/s]
# Fetching encoder.json: 1.05Mit [00:00, 3.23Mit/s]
# Fetching hparams.json: 1.05Mit [00:00, 599Mit/s]
# Fetching model.ckpt.data-00000-of-00001: 498Mit [00:27, 17.8Mit/s]
# Fetching model.ckpt.index: 1.05Mit [00:00, 791Mit/s]
# Fetching model.ckpt.meta: 1.05Mit [00:00, 3.89Mit/s]
# Fetching vocab.bpe: 1.05Mit [00:00, 4.17Mit/s]

# %%
raw_data = "/content/drive/MyDrive/bot/filename.txt"

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data = []
with open(raw_data) as f: # Default file operation mode is `r'
  items = f.readlines()
  data.append(items)

# %%
#import json


with open(raw_data, 'r') as f:
    df = f.readlines()


data = []

data.append(df)

# %%
with open('chatbot.txt', 'w') as f:
     for line in data:
        try:
            f.write(line)
            f.write('\n')
        except:
            pass

# %%
file_name = "/content/chatbot.txt"

# %%
sess = gpt2.start_tf_sess()

# %%
gpt2.finetune(sess,
              dataset=raw_data,
              model_name='124M',
              steps=500,
              restore_from='fresh',
              run_name='run1',
              print_every=10,
              sample_every=100,
              save_every=100
              )
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/gpt_2_simple/src/sample.py:17: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Loading checkpoint models/124M/model.ckpt
# INFO:tensorflow:Restoring parameters from models/124M/model.ckpt
# Loading dataset...
# 100%|██████████| 1/1 [00:04<00:00,  4.40s/it]
# dataset has 1021963 tokens
# Training...
# [10 | 28.28] loss=0.65 avg=0.65
# [20 | 50.26] loss=0.58 avg=0.61
# [30 | 72.74] loss=0.68 avg=0.64
# [40 | 95.76] loss=0.50 avg=0.60
# [50 | 119.73] loss=0.51 avg=0.58
# [60 | 143.81] loss=0.49 avg=0.57
# [70 | 167.20] loss=0.60 avg=0.57
# [80 | 190.77] loss=0.52 avg=0.56
# [90 | 214.69] loss=0.43 avg=0.55
# [100 | 238.35] loss=0.51 avg=0.54
# Saving checkpoint/run1/model-100
# ======== SAMPLE 1 ========
#
# Question: I'm a fan
# Answer: I'm the best.
# ...

# %%
#while True:
#  ques = input("[YOU] : ")

 # inp = '[BOT] :'

  #x = gpt2.generate(sess,
   #             length=20,
    #            temperature = 0.6,
     #           include_prefix=False,
      #          prefix=inp,
       #         nsamples=1,
        #        )

# %%
print("Hello!")

while True:
  #ques = input("Question : ")
  #audio_text()
  inp = input()

  if inp.lower() == "quit": 
    break
  
  x = gpt2.generate(sess,
                    length=15,
                    temperature = 0.6,
                    include_prefix=False,
                    prefix=inp,
                    nsamples=1,
                    return_as_list=True)[0] 
  #eng = x

  #text_audio()
  print(x)
# Out:
# Hello!
# hello
# hello.
# Question: I suspect you're fake
# Answer: You're definitely
# how are you?
# how are you?
# Answer: I'm digital, so I'm always just... here.
# are you human?
# are you human?
# Answer: I'm digital. In other words, I'm not human
# what  are you doing?
# what  are you doing?
# Answer: I'm always happy to chat.
# Question: Are you
# do you like reading?
# do you like reading?
# Answer: I like a lot of stuff.
# Question: Do you
# what is your favourite color?
# what is your favourite color?
# Answer: I'm quite fond of blue.
# Question: What is
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
# ...

# %%
#!apt install libasound2-dev portaudio19-dev libportaudio2 libportaudiocpp0 ffmpeg
#!pip install pydub
#!pip install speechrecognition
#!pip install pyaudio
#!pip install pyttsx3
# !pip install gTTS

# %%
#!pip install SpeechRecognition
import speech_recognition as sr

def audio_text():
    r = sr.Recognizer()
    with sr.Microphone() as source:
        r_adjust_for_ambient_noise(source)
    audio = r.listen(source)
    try:
        inp = input("You: " + r.recognize_google(audio))
    except Exception as e:
        print("Error " + str(e))

    return inp

# %%
import pyttsx3

def text_audio(eng):
    engine = pyttsx3.init()
    engine.setProperty("rate",120)
    engine.say(eng)
    engine.runAndWait()
